# %% [markdown]
# <a href="https://colab.research.google.com/github/unnatissrivastava/SalarySage/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
#series
country = ["india", "america", "australia"]
pd.Series(country)
# Out:
# 0        india
# 1      america
# 2    australia
# dtype: object

# %%
import numpy as np
import pandas as pd
subject = ["maths", "physics", "chemistry"]
marks = ["98","85","99"]
pd.Series(subject, index = marks)
# Out:
# 98        maths
# 85      physics
# 99    chemistry
# dtype: object

# %%
#series from dict
marks = {
    'maths' : 67,
    'english' : 77,
    'hindi' : 100
    }
marks_series = pd.Series(marks,name = 'unnati ke marks')
marks_series
# Out:
# maths       67
# english     77
# hindi      100
# Name: unnati ke marks, dtype: int64

# %% [markdown]
# SERIES ATTRIBUTES

# %%
#size
marks_series.size
#dtype
marks_series.dtype
#name
marks_series.name
#is_unique
marks_series.is_unique
#index
marks_series.index
#values
marks_series.values

# %%
# !ls /content
# Out:
# sample_data  students.csv

# %%
import pandas as pd
subs = pd.read_csv('/content/netflix_dataset.csv')
subs
# Out:
#    show_id              title     type  release_year        genre country  \
# 0    s0001    Netflix Title 1    Movie          2010  Documentary   India
# 1    s0002    Netflix Title 2    Movie          2023        Drama     USA
# 2    s0003    Netflix Title 3    Movie          2016  Documentary   Spain
# 3    s0004    Netflix Title 4  TV Show          2010      Romance   Japan
# 4    s0005    Netflix Title 5    Movie          2016      Romance   India
# ..     ...                ...      ...           ...          ...     ...
# 95   s0096   Netflix Title 96  TV Show          2010      Romance  Canada
# 96   s0097   Netflix Title 97  TV Show          2024  Documentary      UK
# 97   s0098   Netflix Title 98  TV Show          2025     Thriller  Canada
# 98   s0099   Netflix Title 99    Movie          2012       Action  Canada
# 99   s0100  Netflix Title 100  TV Show          2020        Drama  Canada
#
#     rating  duration_min  views_millions
# ...

# %%
pd.read_csv('/content/netflix_dataset.csv', index_col = 'type')
# Out:
#         show_id              title  release_year        genre country  rating  \
# type
# Movie     s0001    Netflix Title 1          2010  Documentary   India     6.1
# Movie     s0002    Netflix Title 2          2023        Drama     USA     5.4
# Movie     s0003    Netflix Title 3          2016  Documentary   Spain     8.2
# TV Show   s0004    Netflix Title 4          2010      Romance   Japan     5.7
# Movie     s0005    Netflix Title 5          2016      Romance   India     5.5
# ...         ...                ...           ...          ...     ...     ...
# TV Show   s0096   Netflix Title 96          2010      Romance  Canada     8.7
# TV Show   s0097   Netflix Title 97          2024  Documentary      UK     7.0
# TV Show   s0098   Netflix Title 98          2025     Thriller  Canada     8.7
# Movie     s0099   Netflix Title 99          2012       Action  Canada     6.1
# TV Show   s0100  Netflix Title 100          2020        Drama  Canada     8.8
#
# ...

# %%
#used to show preview
subs.head()
# Out:
#   show_id            title     type  release_year        genre country  \
# 0   s0001  Netflix Title 1    Movie          2010  Documentary   India
# 1   s0002  Netflix Title 2    Movie          2023        Drama     USA
# 2   s0003  Netflix Title 3    Movie          2016  Documentary   Spain
# 3   s0004  Netflix Title 4  TV Show          2010      Romance   Japan
# 4   s0005  Netflix Title 5    Movie          2016      Romance   India
#
#    rating  duration_min  views_millions
# 0     6.1            77           184.4
# 1     5.4            89           126.8
# 2     8.2           113            55.9
# 3     5.7           114            85.7
# 4     5.5           108            25.1

# %%
#gives top 10 rows
subs.head(10)
# Out:
#   show_id             title     type  release_year        genre country  \
# 0   s0001   Netflix Title 1    Movie          2010  Documentary   India
# 1   s0002   Netflix Title 2    Movie          2023        Drama     USA
# 2   s0003   Netflix Title 3    Movie          2016  Documentary   Spain
# 3   s0004   Netflix Title 4  TV Show          2010      Romance   Japan
# 4   s0005   Netflix Title 5    Movie          2016      Romance   India
# 5   s0006   Netflix Title 6  TV Show          2018      Romance     USA
# 6   s0007   Netflix Title 7  TV Show          2012       Sci-Fi   India
# 7   s0008   Netflix Title 8  TV Show          2016  Documentary     USA
# 8   s0009   Netflix Title 9    Movie          2017      Romance     USA
# 9   s0010  Netflix Title 10  TV Show          2015       Action   India
#
#    rating  duration_min  views_millions
# 0     6.1            77           184.4
# 1     5.4            89           126.8
# 2     8.2           113            55.9
# ...

# %%
#gives bottom rows
subs.tail(10)
# Out:
#    show_id              title     type  release_year        genre  \
# 90   s0091   Netflix Title 91  TV Show          2018      Romance
# 91   s0092   Netflix Title 92    Movie          2015       Action
# 92   s0093   Netflix Title 93  TV Show          2022  Documentary
# 93   s0094   Netflix Title 94    Movie          2013  Documentary
# 94   s0095   Netflix Title 95    Movie          2011       Action
# 95   s0096   Netflix Title 96  TV Show          2010      Romance
# 96   s0097   Netflix Title 97  TV Show          2024  Documentary
# 97   s0098   Netflix Title 98  TV Show          2025     Thriller
# 98   s0099   Netflix Title 99    Movie          2012       Action
# 99   s0100  Netflix Title 100  TV Show          2020        Drama
#
#         country  rating  duration_min  views_millions
# 90        India     5.8           137           241.0
# 91          USA     7.6           178            78.7
# 92           UK     5.3           148           207.8
# ...

# %%
#randomly displays one row
subs.sample()
# Out:
#    show_id             title     type  release_year   genre country  rating  \
# 27   s0028  Netflix Title 28  TV Show          2013  Comedy      UK     5.3
#
#     duration_min  views_millions
# 27            62           147.5

# %%
#shows frequency of each item
import pandas as pd
subs = pd.read_csv('/content/netflix_dataset.csv')
subs.value_counts()
# Out:
# show_id  title              type     release_year  genre        country  rating  duration_min  views_millions
# s0001    Netflix Title 1    Movie    2010          Documentary  India    6.1     77            184.4             1
# s0002    Netflix Title 2    Movie    2023          Drama        USA      5.4     89            126.8             1
# s0003    Netflix Title 3    Movie    2016          Documentary  Spain    8.2     113           55.9              1
# s0004    Netflix Title 4    TV Show  2010          Romance      Japan    5.7     114           85.7              1
# s0005    Netflix Title 5    Movie    2016          Romance      India    5.5     108           25.1              1
#                                                                                                                 ..
# s0096    Netflix Title 96   TV Show  2010          Romance      Canada   8.7     73            108.9             1
# ...

# %%
#sorts in ascending values
subs.sort_values(by='release_year')
# Out:
#    show_id             title     type  release_year        genre country  \
# 0    s0001   Netflix Title 1    Movie          2010  Documentary   India
# 3    s0004   Netflix Title 4  TV Show          2010      Romance   Japan
# 61   s0062  Netflix Title 62  TV Show          2010        Drama   India
# 47   s0048  Netflix Title 48  TV Show          2010  Documentary   Japan
# 52   s0053  Netflix Title 53  TV Show          2010        Drama     USA
# ..     ...               ...      ...           ...          ...     ...
# 30   s0031  Netflix Title 31    Movie          2025       Comedy   Japan
# 87   s0088  Netflix Title 88    Movie          2025        Drama   Spain
# 77   s0078  Netflix Title 78  TV Show          2025  Documentary      UK
# 72   s0073  Netflix Title 73  TV Show          2025     Thriller      UK
# 97   s0098  Netflix Title 98  TV Show          2025     Thriller  Canada
#
#     rating  duration_min  views_millions
# 0      6.1            77           184.4
# ...

# %%
#sort_values() sorts the values of a Series or the rows of a DataFrame in ascending or descending order.
subs.sort_values(by='release_year', ascending=False).head(1)
# Out:
#    show_id             title   type  release_year   genre country  rating  \
# 30   s0031  Netflix Title 31  Movie          2025  Comedy   Japan     7.1
#
#     duration_min  views_millions
# 30           112            48.4

# %%
#sort_index() sorts a Series or DataFrame based on its index (row labels or column labels), not the values.
subs.sort_index(inplace = True)
subs
# Out:
#    show_id              title     type  release_year        genre country  \
# 0    s0001    Netflix Title 1    Movie          2010  Documentary   India
# 1    s0002    Netflix Title 2    Movie          2023        Drama     USA
# 2    s0003    Netflix Title 3    Movie          2016  Documentary   Spain
# 3    s0004    Netflix Title 4  TV Show          2010      Romance   Japan
# 4    s0005    Netflix Title 5    Movie          2016      Romance   India
# ..     ...                ...      ...           ...          ...     ...
# 95   s0096   Netflix Title 96  TV Show          2010      Romance  Canada
# 96   s0097   Netflix Title 97  TV Show          2024  Documentary      UK
# 97   s0098   Netflix Title 98  TV Show          2025     Thriller  Canada
# 98   s0099   Netflix Title 99    Movie          2012       Action  Canada
# 99   s0100  Netflix Title 100  TV Show          2020        Drama  Canada
#
#     rating  duration_min  views_millions
# ...

# %%
#describe() generates summary statistics of a Series or DataFrame.
subs.describe()
# Out:
#        release_year      rating  duration_min  views_millions
# count    100.000000  100.000000    100.000000      100.000000
# mean    2017.250000    7.212000    118.120000      128.775000
# std        4.515685    1.285842     33.573462       73.078645
# min     2010.000000    5.000000     62.000000        2.400000
# 25%     2013.000000    6.075000     89.000000       68.550000
# 50%     2017.500000    7.100000    116.000000      129.150000
# 75%     2021.000000    8.325000    145.250000      189.825000
# max     2025.000000    9.500000    180.000000      249.600000

# %%
subs.max()
# Out:
# show_id                      s0100
# title             Netflix Title 99
# type                       TV Show
# release_year                  2025
# genre                     Thriller
# country                        USA
# rating                         9.5
# duration_min                   180
# views_millions               249.6
# dtype: object

# %%
subs.min()
# Out:
# show_id                     s0001
# title             Netflix Title 1
# type                        Movie
# release_year                 2010
# genre                      Action
# country                    Canada
# rating                        5.0
# duration_min                   62
# views_millions                2.4
# dtype: object

# %%
subs.count()
# Out:
# show_id           100
# title             100
# type              100
# release_year      100
# genre             100
# country           100
# rating            100
# duration_min      100
# views_millions    100
# dtype: int64

# %%
subs.sum()
# Out:
# show_id           s0001s0002s0003s0004s0005s0006s0007s0008s0009s...
# title             Netflix Title 1Netflix Title 2Netflix Title 3N...
# type              MovieMovieMovieTV ShowMovieTV ShowTV ShowTV Sh...
# release_year                                                 201725
# genre             DocumentaryDramaDocumentaryRomanceRomanceRoman...
# country           IndiaUSASpainJapanIndiaUSAIndiaUSAUSAIndiaSpai...
# rating                                                        721.2
# duration_min                                                  11812
# views_millions                                              12877.5
# dtype: object

# %%
#mean() returns the average of numeric values in a Series or DataFrame.
subs.mean(numeric_only=True)
# Out:
# release_year      2017.250
# rating               7.212
# duration_min       118.120
# views_millions     128.775
# dtype: float64

# %%
#median() returns the middle value of a numeric Series or DataFrame after sorting the data.
subs.median(numeric_only = True)
# Out:
# release_year      2017.50
# rating               7.10
# duration_min       116.00
# views_millions     129.15
# dtype: float64

# %%
#mode() returns the most frequently occurring value(s) in a Series or DataFrame.
subs.mode(numeric_only = True)
# Out:
#    release_year  rating  duration_min  views_millions
# 0        2020.0     5.7         145.0            70.4
# 1        2022.0     NaN           NaN           121.9
# 2           NaN     NaN           NaN           126.8

# %%
subs.iloc[:5]
# Out:
#   show_id            title     type  release_year        genre country  \
# 0   s0001  Netflix Title 1    Movie          2010  Documentary   India
# 1   s0002  Netflix Title 2    Movie          2023        Drama     USA
# 2   s0003  Netflix Title 3    Movie          2016  Documentary   Spain
# 3   s0004  Netflix Title 4  TV Show          2010      Romance   Japan
# 4   s0005  Netflix Title 5    Movie          2016      Romance   India
#
#    rating  duration_min  views_millions
# 0     6.1            77           184.4
# 1     5.4            89           126.8
# 2     8.2           113            55.9
# 3     5.7           114            85.7
# 4     5.5           108            25.1

# %% [markdown]
# Code	     |||            Meaning
#
# subs[0]      --->	Column named 0 ❌
#
# subs['title']--->	title column ✅
#
# subs.iloc[0] --->	First row (position-based) ✅
#
# subs.loc[0]	 ---> Row whose index label is 0 ✅ (only if index contains 0)

# %%
a = pd.Series([1,2,3,4,5,6,7])
a[2]
# Out:
# np.int64(3)

# %%
print(len(subs))
# Out:
# 100

# %%
print(type(subs))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(dir(subs))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__'
# ...

# %%
print(sorted(subs))
# Out:
# ['country', 'duration_min', 'genre', 'rating', 'release_year', 'show_id', 'title', 'type', 'views_millions']

# %%
'Netflix Title 1200' in subs
# Out:
# False

# %%
import pandas as pd
subs = pd.read_csv('/content/netflix_dataset.csv')
100 - subs['release_year']
# Out:
# 0    -1910
# 1    -1923
# 2    -1916
# 3    -1910
# 4    -1916
#       ...
# 95   -1910
# 96   -1924
# 97   -1925
# 98   -1912
# 99   -1920
# Name: release_year, Length: 100, dtype: int64

# %%
print(type(subs))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
subs[subs['views_millions'] >= 50]
# Out:
#    show_id              title     type  release_year        genre country  \
# 0    s0001    Netflix Title 1    Movie          2010  Documentary   India
# 1    s0002    Netflix Title 2    Movie          2023        Drama     USA
# 2    s0003    Netflix Title 3    Movie          2016  Documentary   Spain
# 3    s0004    Netflix Title 4  TV Show          2010      Romance   Japan
# 6    s0007    Netflix Title 7  TV Show          2012       Sci-Fi   India
# ..     ...                ...      ...           ...          ...     ...
# 95   s0096   Netflix Title 96  TV Show          2010      Romance  Canada
# 96   s0097   Netflix Title 97  TV Show          2024  Documentary      UK
# 97   s0098   Netflix Title 98  TV Show          2025     Thriller  Canada
# 98   s0099   Netflix Title 99    Movie          2012       Action  Canada
# 99   s0100  Netflix Title 100  TV Show          2020        Drama  Canada
#
#     rating  duration_min  views_millions
# ...

# %%
subs[subs['views_millions'] >= 200].size
# Out:
# 207

# %%
subs.plot()
# Out:
# <Axes: >
